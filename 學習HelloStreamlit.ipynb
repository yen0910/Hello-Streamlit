# %% [markdown]
# <a href="https://colab.research.google.com/github/yen0910/Hello-Streamlit/blob/main/%E5%AD%B8%E7%BF%92HelloStreamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 這是一個非常完整的實作流程。為了讓學生在 **90 分鐘**內順利完成從「複製範本」，修改檔名，學**習**HelloStreamlit.ipynb，到「產出 QR Code」的過程，
# 整理了這份詳細的教學指南，特別加入了**學習歷程檔案**的撰寫建議與**口試委員實境模擬**的亮點說明。
#
#
#
# ---

# %% [markdown]
# ### 🎓 **第一週** 90 分鐘極速開發實戰：個人雲端作品集， python檔案，發佈在 Streamlit的基本練習

# %% [markdown]
# #### **第一階段**：獲取老師的範本 (10 分鐘)

# %% [markdown]
# 1. **進入老師專案**：點擊老師提供的 GitHub 網址：`https://github.com/PeterShiaush/Hello-Streamlit`。
# 2. **開啟 Colab**：在檔案清單中，點選副檔名為 `.ipynb` 的筆記本檔案，接著點擊上方的 **「Open in Colab」** 按鈕。
# 3. **儲存副本 (最關鍵步驟)**：進入 Colab 後，請點選左上角「檔案」 > **「在雲端硬碟儲存副本」**。
# 4. 修改檔名，學**習**HelloStreamlit.ipynb
# * *注意：若沒做這一步，你將無法儲存任何修改，一定要在自己的 Google Drive 建立副本。*
#
# ---

# %% [markdown]
# #### **第二階段**：程式個人化與身分判斷實作 (20 分鐘)
#
# 在自己的 Colab 中，修改變數定義區，並執行程式碼產生 `streamlit_app.py` 檔案。

# %%
# %%writefile streamlit_app.py
# 第一行指令：%%writefile 會將此儲存格內容直接寫入成一個名為 streamlit_app.py 的檔案
# 第二行用途：這是在雲端開發環境中產生可執行腳本的標準做法
import streamlit as st

# ==========================================
# 1. 開發者變數定義區 (請在此修改個人學籍資訊)
# ==========================================
dev_name = "莊振喭"                # 學生姓名
dev_class = "高二 12班"            # 班級
dev_id = "311325"               # 學號
dev_group = "自然組"               # 組別 (自然組 或 自學組)
dev_skills = ["Python", "GitHub", "Streamlit", "Colab"]

# ==========================================
# 2. 網頁配置與側邊欄 (Layout Layer)
# ==========================================
st.set_page_config(page_title=f"{dev_name} 的作品展示", page_icon="🔬")

with st.sidebar:
    st.header("👨‍💻 開發者檔案")
    st.image("https://cdn-icons-png.flaticon.com/512/3242/3242257.png", width=100)
    st.markdown(f"**姓名：** {dev_name}\n**班級：** {dev_class}\n**學號：** {dev_id}\n**組別：** {dev_group}")
    st.divider()
    st.subheader("🛠 技術工具")
    for skill in dev_skills:
        st.write(f"- {skill}")
    st.caption("本專案透過 GitHub CI/CD 自動化部署")

# ==========================================
# 3. 主頁面：問候與互動特效 (Logic Layer)
# ==========================================
st.title("✨ 雲端 Python 互動展示")
visitor = st.text_input("老師/委員您好，請輸入您的姓名：", placeholder="例如：林阿宏委員 或 王小明老師")

if visitor:
    # 關鍵字偵測：包含「委員」或「老師」時觸發氣球特效
    if "委員" in visitor or "老師" in visitor:
        st.balloons() # 觸發氣球噴發特效
        st.success(f"### 歡迎 {visitor} 蒞臨指導！ 👋")
    else:
        st.write(f"### Hello, {visitor}! 😊")
        st.info("提示：輸入包含「委員」或「老師」可觸發隱藏特效！")
else:
    st.info("💡 請在上方輸入框輸入姓名，啟動 Python 的互動邏輯！")
# Out:
# Writing streamlit_app.py

# %% [markdown]
# ---

# %% [markdown]
# #### **第三階段**：GitHub 與 Streamlit 部署 (30 分鐘)

# %% [markdown]
# 1. **建立個人倉庫**：登入 GitHub，建立一個 **Public** (公開)，python 倉庫，命名為 `Hello-Streamlit`。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. **上傳檔案**：
#
# *   將 Colab 學生HelloStreamlit.ipynb改名 "HelloStreamlit.ipynb"，在GitHub中儲存副本
# *   將 Colab 左側資料夾產出的 `streamlit_app.py` 下載，並上傳至 GitHub。
#
#
# 3. **設定環境檔**：在 GitHub 新增檔案 `requirements.txt`，內容填寫 `streamlit`。為什麼要這樣做？
# *   雲端部署：當你將應用程式部署到 Streamlit Community Cloud 或其他雲端平台時，系統會自動讀取此檔案並安裝必要的 Python 套件。
# *   環境管理：這能確保其他人在執行你的程式碼時，能安裝正確版本的套件。
# 4. **自動部署**：
# * 前往 [Streamlit Cloud](https://share.streamlit.io/) 並登入 GitHub。
# * 點擊 **Create app**，連結你的 `Hello-Streamlit` 倉庫。
# * 點擊 **Deploy**。等待約 2 分鐘，看到網頁出現即代表部署成功！
#
#
#
#
#
# ---

# %% [markdown]
# #### **第四階段**：**建立 QR Code** (5 分鐘)

# %% [markdown]
# 1. 複製部署後的網頁網址。
# 2. 使用線上 QR Code 產生器將網址轉為條碼，貼在你的三折頁或簡報中。

# %% [markdown]
# **展示如下:**
#
# https://hello-app-6nuygye3oggsqs5s7ksi6q.streamlit.app/
#
# 此網址已經 轉 QR code，如下，請手機掃描

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **第五階段**：學習歷程與口試實境模擬 (30 分鐘)

# %% [markdown]
# ##### 1. 學習歷程檔案撰寫要點
#
# * **技術名稱**：基於雲端架構的 Python 互動網頁開發。
# * **所學內容**：
# * **雲端開發流程**：從 Google Colab 編寫腳本，透過 GitHub 版本控制，最終實現 Streamlit Cloud 自動化部署。
# * **字串處理邏輯**：練習使用 Python 的 `in` 運算子進行關鍵字過濾，實現動態使用者回饋。
#
#
# * **反思與應用**：了解「代碼即服務 (SaaS)」的概念，未來可將科學數據處理轉化為互動網頁。

# %% [markdown]
# ##### 2. 自然組口試展示亮點 (引導學生向委員解釋)
#
# * **展示邏輯控制能力**：
# > 「委員好，我在系統中設計了 **『身分識別邏輯』**。當系統偵測到『老師』或『委員』關鍵字時，會自動觸發氣球噴發特效，這展現了我對 Python 條件判斷 (`if-else`) 與字串處理的掌握。」
#
#
# * **展示架構現代化思維**：
# > 「這套作品整合了 **GitHub** 與 **Streamlit Cloud**。這代表我實作了現代軟體開發中的 **CI/CD (持續整合與部署)** 流程。我只要在 GitHub 修改代碼，雲端網頁就會即時更新。」
#
#
# * **展示模組化與維護性**：
# > 「我的程式碼採用 **變數與清單 (`List`)** 管理個人資料。這展現了良好的程式維護性，未來若需新增技術工具，只需修改變數，介面就會自動同步更新。」
#
#
#
# ---

# %% [markdown]
# #### **第六階段**：在 Android 和 iPhone 上將它「安裝」到主畫面，**假裝是App**

# %% [markdown]
# 推薦方式：將 Streamlit App 安裝為 PWA
# 對於您的 Streamlit 應用程式 https://hello-app-????????9999.streamlit.app/，
# 可以透過以下簡單步驟在 Android 和 iPhone 上將它「安裝」到主畫面：

# %% [markdown]
# 在 Android 手機上：
# 開啟 Chrome 瀏覽器。
# 輸入或貼上您的 Streamlit 網址：https://hello-app-6nuygye3oggsqs5s7ksi6q.streamlit.app/ 並前往。
# 點擊瀏覽器右上角的 三個點（選單按鈕）。
# 在選單中找到並點擊 「安裝應用程式」 或 「新增至主畫面」。
# 按照提示完成安裝，您的 Streamlit App 圖示就會出現在主畫面中，點擊即可開啟，就像一個獨立的 App 一樣。

# %% [markdown]
# 在 iPhone 上：
# 開啟 Safari 瀏覽器 (PWA 在 Safari 上的支援度最佳)。
# 輸入或貼上您的 Streamlit 網址：https://hello-app-6nuygye3oggsqs5s7ksi6q.streamlit.app/ 並前往。
# 點擊瀏覽器底部的 「分享」按鈕 (方形圖示，上面有一個箭頭向上指)。
# 在分享選單中，向下滑動並點擊 「加入主畫面」。
# 您可以編輯應用程式的名稱，然後點擊右上角的 「新增」。您的 Streamlit App 圖示就會出現在主畫面中，點擊即可開啟。
